# %% [markdown]
# # Chapter 01 - API Basics
# ## Common Conventions and API Elements of scikit-learn
# This notebook covers the core scikit-learn workflow: datasets, train/test split, preprocessing, pipelines, model training, evaluation, and visualization.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay
plt.style.use('ggplot')

# %% [markdown]
# ## 1. Load Dataset

# %%
iris = load_iris(as_frame=True)
X = iris.data
y = iris.target
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# ## 2. Quick Visualization

# %%
plt.figure(figsize=(8,5))
plt.scatter(X.iloc[:,0], X.iloc[:,2], c=y, s=60)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.title('Iris Dataset Overview')
plt.show()

# %% [markdown]
# ## 3. Train/Test Split + Pipeline

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42, stratify=y)
pipe = Pipeline([('scaler', StandardScaler()), ('model', KNeighborsClassifier(n_neighbors=5))])
pipe.fit(X_train, y_train)
pred = pipe.predict(X_test)
acc = accuracy_score(y_test, pred)
print('Accuracy:', round(acc,4))
# Out:
# Accuracy: 0.9211

# %% [markdown]
# ## 4. Confusion Matrix

# %%
fig, ax = plt.subplots(figsize=(6,5))
ConfusionMatrixDisplay.from_predictions(y_test, pred, ax=ax)
plt.title('Model Performance')
plt.show()

# %% [markdown]
# ## Important Concepts
# - **Estimator**: object with `.fit()` method.
# - **Predictor**: model using `.predict()`.
# - **Transformer**: object using `.transform()` (e.g., scaler).
# - **Pipeline**: chains preprocessing + model.
# - **Train/Test Split**: evaluate generalization.

# %% [markdown]
# ## Summary
# This chapter introduced the standard scikit-learn API. Most workflows follow: load data → split data → preprocess → fit model → predict → evaluate.
